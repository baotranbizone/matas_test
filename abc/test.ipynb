# %%
import json
context_json = dbutils.notebook.entry_point.getDbutils().notebook().getContext().safeToJson()
context_dict = json.loads(context_json)
notebook_path = context_dict.get("attributes", {}).get("notebook_path")
 
print(context_dict.get("attributes", {}).get("mlflowGitRelativePath", notebook_path))

# %%
print('a')
